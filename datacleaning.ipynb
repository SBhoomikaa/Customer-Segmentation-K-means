# %%
import pandas as pd

# %%
df=pd.read_csv('bank_transactions.csv')

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053     10/1/94          F     JAMSHEDPUR
# 1                  T2   C2142763      4/4/57          M        JHAJJAR
# 2                  T3   C4417068    26/11/96          F         MUMBAI
# 3                  T4   C5342380     14/9/73          F         MUMBAI
# 4                  T5   C9031234     24/3/88          F    NAVI MUMBAI
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229      8/4/90          M      NEW DELHI
# 1048563      T1048564   C6459278     20/2/92          M         NASHIK
# 1048564      T1048565   C6412354     18/5/89          M      HYDERABAD
# 1048565      T1048566   C6420483     30/8/78          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524      5/3/84          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df.describe()
# Out:
#        CustAccountBalance  TransactionTime  TransactionAmount (INR)
# count        1.046198e+06     1.048567e+06             1.048567e+06
# mean         1.154035e+05     1.570875e+05             1.574335e+03
# std          8.464854e+05     5.126185e+04             6.574743e+03
# min          0.000000e+00     0.000000e+00             0.000000e+00
# 25%          4.721760e+03     1.240300e+05             1.610000e+02
# 50%          1.679218e+04     1.642260e+05             4.590300e+02
# 75%          5.765736e+04     2.000100e+05             1.200000e+03
# max          1.150355e+08     2.359590e+05             1.560035e+06

# %%
df.drop_duplicates()
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053     10/1/94          F     JAMSHEDPUR
# 1                  T2   C2142763      4/4/57          M        JHAJJAR
# 2                  T3   C4417068    26/11/96          F         MUMBAI
# 3                  T4   C5342380     14/9/73          F         MUMBAI
# 4                  T5   C9031234     24/3/88          F    NAVI MUMBAI
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229      8/4/90          M      NEW DELHI
# 1048563      T1048564   C6459278     20/2/92          M         NASHIK
# 1048564      T1048565   C6412354     18/5/89          M      HYDERABAD
# 1048565      T1048566   C6420483     30/8/78          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524      5/3/84          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
import numpy as np

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053     10/1/94          F     JAMSHEDPUR
# 1                  T2   C2142763      4/4/57          M        JHAJJAR
# 2                  T3   C4417068    26/11/96          F         MUMBAI
# 3                  T4   C5342380     14/9/73          F         MUMBAI
# 4                  T5   C9031234     24/3/88          F    NAVI MUMBAI
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229      8/4/90          M      NEW DELHI
# 1048563      T1048564   C6459278     20/2/92          M         NASHIK
# 1048564      T1048565   C6412354     18/5/89          M      HYDERABAD
# 1048565      T1048566   C6420483     30/8/78          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524      5/3/84          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df['CustomerDOB'] = pd.to_datetime(df['CustomerDOB'], format='%d/%m/%y', errors='coerce')

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053  1994-01-10          F     JAMSHEDPUR
# 1                  T2   C2142763  2057-04-04          M        JHAJJAR
# 2                  T3   C4417068  1996-11-26          F         MUMBAI
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229  1990-04-08          M      NEW DELHI
# 1048563      T1048564   C6459278  1992-02-20          M         NASHIK
# 1048564      T1048565   C6412354  1989-05-18          M      HYDERABAD
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df = df[(df['CustomerDOB'].dt.year >= 1900) & (df['CustomerDOB'].dt.year <= 2004)]

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053  1994-01-10          F     JAMSHEDPUR
# 2                  T3   C4417068  1996-11-26          F         MUMBAI
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# 5                  T6   C1536588  1972-10-08          F       ITANAGAR
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229  1990-04-08          M      NEW DELHI
# 1048563      T1048564   C6459278  1992-02-20          M         NASHIK
# 1048564      T1048565   C6412354  1989-05-18          M      HYDERABAD
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df = df[df['CustomerDOB'] != 'NaT']

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053  1994-01-10          F     JAMSHEDPUR
# 2                  T3   C4417068  1996-11-26          F         MUMBAI
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# 5                  T6   C1536588  1972-10-08          F       ITANAGAR
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229  1990-04-08          M      NEW DELHI
# 1048563      T1048564   C6459278  1992-02-20          M         NASHIK
# 1048564      T1048565   C6412354  1989-05-18          M      HYDERABAD
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df['TransactionAmount (INR)'].max()
# Out:
# 1560034.99

# %%
df = df[df['TransactionAmount (INR)'] >= 1000]

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# 12                T13   C6339347  1978-06-13          M      AHMEDABAD
# 24                T25   C1219943  1991-05-17          F        GURGAON
# 26                T27   C5430368  1986-02-01          M          DELHI
# ...               ...        ...         ...        ...            ...
# 1048556      T1048557   C3414578  1990-09-10          F        GURGAON
# 1048560      T1048561   C5028150  1980-05-24          M           PUNE
# 1048561      T1048562   C1034220  1992-11-19          M      BANGALORE
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df['TransactionAmount (INR)'].describe()
# Out:
# count    2.613450e+05
# mean     4.049912e+03
# std      1.053830e+04
# min      1.000000e+03
# 25%      1.315000e+03
# 50%      1.996450e+03
# 75%      3.490000e+03
# max      1.560035e+06
# Name: TransactionAmount (INR), dtype: float64

# %%
df = df[df['TransactionAmount (INR)'] <= 100000]

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# 12                T13   C6339347  1978-06-13          M      AHMEDABAD
# 24                T25   C1219943  1991-05-17          F        GURGAON
# 26                T27   C5430368  1986-02-01          M          DELHI
# ...               ...        ...         ...        ...            ...
# 1048556      T1048557   C3414578  1990-09-10          F        GURGAON
# 1048560      T1048561   C5028150  1980-05-24          M           PUNE
# 1048561      T1048562   C1034220  1992-11-19          M      BANGALORE
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df['TransactionAmount (INR)'].describe()
# Out:
# count    261111.000000
# mean       3877.352089
# std        7134.333854
# min        1000.000000
# 25%        1315.000000
# 50%        1995.000000
# 75%        3480.000000
# max      100000.000000
# Name: TransactionAmount (INR), dtype: float64

# %%
df = df[df['CustAccountBalance'] >= 1000]

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# 12                T13   C6339347  1978-06-13          M      AHMEDABAD
# 24                T25   C1219943  1991-05-17          F        GURGAON
# 27                T28   C2416848  1993-04-01          M        CHENNAI
# ...               ...        ...         ...        ...            ...
# 1048555      T1048556   C2122724  1978-03-20          M      FARIDABAD
# 1048556      T1048557   C3414578  1990-09-10          F        GURGAON
# 1048561      T1048562   C1034220  1992-11-19          M      BANGALORE
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df = df[df['TransactionAmount (INR)'] <= df['CustAccountBalance']]

# %%
df['CustomerDOB'].describe()
# Out:
# count                           225635
# mean     1984-10-18 18:08:25.740687424
# min                1969-01-01 00:00:00
# 25%                1980-05-09 00:00:00
# 50%                1985-09-15 00:00:00
# 75%                1989-10-22 00:00:00
# max                2004-11-18 00:00:00
# Name: CustomerDOB, dtype: object

# %%
count_2_8_16 = (df['TransactionDate'] == '2/8/16').sum()
count_2_8_16
# Out:
# 4296

# %%
count_3_8_16 = (df['TransactionDate'] == '18/9/16').sum()
count_3_8_16
# Out:
# 3491

# %%
df.head()
# Out:
#    TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 3             T4   C5342380  1973-09-14          F       MUMBAI
# 4             T5   C9031234  1988-03-24          F  NAVI MUMBAI
# 12           T13   C6339347  1978-06-13          M    AHMEDABAD
# 24           T25   C1219943  1991-05-17          F      GURGAON
# 27           T28   C2416848  1993-04-01          M      CHENNAI
#
#     CustAccountBalance TransactionDate  TransactionTime  \
# 3            866503.21          2/8/16           142714
# 4              6714.43          2/8/16           181156
# 12            32274.78          2/8/16           203834
# 24             2951.10          3/8/16           124834
# 27            20986.66          3/8/16           160544
#
#     TransactionAmount (INR)
# 3                    2060.0
# 4                    1762.5
# 12                  12300.0
# 24                   1892.0
# 27                   2235.0

# %%
import matplotlib.pyplot as plt

# %%
df['TransactionTime'].describe()
# Out:
# count    225635.000000
# mean     162192.185087
# std       47616.102244
# min           0.000000
# 25%      133443.500000
# 50%      171409.000000
# 75%      200359.000000
# max      235959.000000
# Name: TransactionTime, dtype: float64

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# 12                T13   C6339347  1978-06-13          M      AHMEDABAD
# 24                T25   C1219943  1991-05-17          F        GURGAON
# 27                T28   C2416848  1993-04-01          M        CHENNAI
# ...               ...        ...         ...        ...            ...
# 1048552      T1048553   C5091732  1971-08-21          F      NEW DELHI
# 1048555      T1048556   C2122724  1978-03-20          M      FARIDABAD
# 1048556      T1048557   C3414578  1990-09-10          F        GURGAON
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df['TransactionTime']=df['TransactionTime']/1000
# Out:
# C:\Users\008bh\AppData\Local\Temp\ipykernel_47868\2960845271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TransactionTime']=df['TransactionTime']/1000

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# 12                T13   C6339347  1978-06-13          M      AHMEDABAD
# 24                T25   C1219943  1991-05-17          F        GURGAON
# 27                T28   C2416848  1993-04-01          M        CHENNAI
# ...               ...        ...         ...        ...            ...
# 1048552      T1048553   C5091732  1971-08-21          F      NEW DELHI
# 1048555      T1048556   C2122724  1978-03-20          M      FARIDABAD
# 1048556      T1048557   C3414578  1990-09-10          F        GURGAON
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df['TransactionTime'].describe()
# Out:
# count    218950.000000
# mean        162.281332
# std          47.599432
# min           0.000000
# 25%         133.515000
# 50%         171.452000
# 75%         200.424000
# max         235.959000
# Name: TransactionTime, dtype: float64

# %%
df = df[df['CustAccountBalance'] <= 1000000]

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# 12                T13   C6339347  1978-06-13          M      AHMEDABAD
# 24                T25   C1219943  1991-05-17          F        GURGAON
# 27                T28   C2416848  1993-04-01          M        CHENNAI
# ...               ...        ...         ...        ...            ...
# 1048552      T1048553   C5091732  1971-08-21          F      NEW DELHI
# 1048555      T1048556   C2122724  1978-03-20          M      FARIDABAD
# 1048556      T1048557   C3414578  1990-09-10          F        GURGAON
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
df = df[df['TransactionTime'] >=60]

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# 12                T13   C6339347  1978-06-13          M      AHMEDABAD
# 24                T25   C1219943  1991-05-17          F        GURGAON
# 27                T28   C2416848  1993-04-01          M        CHENNAI
# ...               ...        ...         ...        ...            ...
# 1048552      T1048553   C5091732  1971-08-21          F      NEW DELHI
# 1048555      T1048556   C2122724  1978-03-20          M      FARIDABAD
# 1048556      T1048557   C3414578  1990-09-10          F        GURGAON
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df['TransactionTime'].describe()
# Out:
# count    211506.000000
# mean        167.430313
# std          39.443673
# min          60.009000
# 25%         135.933000
# 50%         172.846000
# 75%         200.917000
# max         235.959000
# Name: TransactionTime, dtype: float64

# %%
df.to_csv('clean_data.csv', index=False)

# %%
df['TransactionDate'] = df['TransactionDate'].str.replace('2016', '2022', regex=True)
# Out:
# C:\Users\008bh\AppData\Local\Temp\ipykernel_47868\3317106216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TransactionDate'] = df['TransactionDate'].str.replace('2016', '2022', regex=True)

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# 12                T13   C6339347  1978-06-13          M      AHMEDABAD
# 24                T25   C1219943  1991-05-17          F        GURGAON
# 27                T28   C2416848  1993-04-01          M        CHENNAI
# ...               ...        ...         ...        ...            ...
# 1048552      T1048553   C5091732  1971-08-21          F      NEW DELHI
# 1048555      T1048556   C2122724  1978-03-20          M      FARIDABAD
# 1048556      T1048557   C3414578  1990-09-10          F        GURGAON
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'], format='%d/%m/%y')

# Change the year to 2022
df['TransactionDate'] = df['TransactionDate'].dt.strftime('2022-%m-%d')
# Out:
# C:\Users\008bh\AppData\Local\Temp\ipykernel_47868\3420454398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TransactionDate'] = pd.to_datetime(df['TransactionDate'], format='%d/%m/%y')
# C:\Users\008bh\AppData\Local\Temp\ipykernel_47868\3420454398.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TransactionDate'] = df['TransactionDate'].dt.strftime('2022-%m-%d')

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# 12                T13   C6339347  1978-06-13          M      AHMEDABAD
# 24                T25   C1219943  1991-05-17          F        GURGAON
# 27                T28   C2416848  1993-04-01          M        CHENNAI
# ...               ...        ...         ...        ...            ...
# 1048552      T1048553   C5091732  1971-08-21          F      NEW DELHI
# 1048555      T1048556   C2122724  1978-03-20          M      FARIDABAD
# 1048556      T1048557   C3414578  1990-09-10          F        GURGAON
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df.to_csv('clean_data.csv', index=False)
